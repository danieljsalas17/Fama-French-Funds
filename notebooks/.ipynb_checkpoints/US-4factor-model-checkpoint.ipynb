# %% [markdown]
# ## Luck vs. Skill (US Large Funds Edition)
#
# Goal of this notebook is to test out the tools I made in the python file `luck_v_skill.py`, as well as try out some new, US data. This uses a 4 factor KAPM model to evaluate alphas.

# %%
import sys
sys.path.insert(0, '../src')

from luck_v_skill import *
# %load_ext autoreload
# %autoreload 2

# %%
# let's me save a jupyter notebook from a code cell
from IPython.display import Javascript

script = '''
require(["base/js/namespace"],function(Jupyter) {
    Jupyter.notebook.save_checkpoint();
});
'''

def notebook_save():
    Javascript(script)
    print('This notebook has been saved')

# %%
labels = pd.read_json('../data/US_funds_colrow_names.json')
labels = labels.sort_values(by='Start')
labels.Start -= 2 # pandas.read_excel() calls first row 0
labels.End -=1
labels
# Out:
#                           Start   End
# Columns                       7     8
# US OE Large Blend             9   948
# US OE Large Value           950  1759
# US OE Large Growth         1762  2725
# US OE Mid-Cap Growth       2728  3178
# US OE Small Value          3180  3484
# US OE Mid-Cap Value        3487  3755
# US OE Small Growth         3758  4261
# US OE Small Blend          4264  4717
# US OE Technology           4720  4834
# US OE Health               4837  4905
# US OE Financial            4908  4975
# US OE Mid-Cap Blend        4978  5255
# US OE Utilities            5258  5310
# US OE Natural Resources    5313  5354
# US OE Equity Energy        5357  5396
# US OE Consumer Cyclical    5399  5426
# US OE Consumer Defensive   5429  5442
# US OE Industrials          5445  5462

# %%
df_xl = pd.read_excel('../data/US Equity Mutual Funds Monthly Returns.xlsx')

# %%
columns = df_xl.iloc[labels.loc['Columns','Start'],:].values

# %%
for i in range(3,len(columns)):
    columns[i] = columns[i].replace("Monthly Return ",'')

# %%
row[0]
# Out:
# 'US OE Industrials'

# %%
dfs = {}
for i,row in enumerate(labels.iterrows()):
    if i:
        s,f = row[1].Start,row[1].End
        df = pd.DataFrame(data=df_xl.iloc[s:f,:].values,columns=columns)
        no_tick = df.iloc[:,1].isna()
        df.iloc[df.index[no_tick],1] = df.iloc[df.index[no_tick],0]
        df.drop(columns = df.columns[[0,2]],inplace=True)
        df.set_index(df.columns[0])
        df = df.T
        df.index = pd.to_datetime(df.index)
        dfs[row[0]] = df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-c290fffc10c8> in <module>
#       6         no_tick = df.iloc[:,1].isna()
#       7         df.iloc[df.index[no_tick],1] = df.iloc[df.index[no_tick],0]
# ----> 8         df.drop(columns = df.columns[0,2],inplace=True)
#       9         df.set_index(df.columns[0])
#      10         df = df.T
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    2093
#    2094         key = com._values_from_object(key)
# -> 2095         result = getitem(key)
#    2096         if not is_scalar(result):
#    2097             return promote(result)
#
# IndexError: too many indices for array

# %%
# Out:
# 7                             Group/Investment Ticker    Fund Size  \
# 9                            US OE Large Blend    NaN          NaN
# 10                     Alger Growth & Income A  ALBAX    111949623
# 11                     Alger Growth & Income C  ALBCX    111949623
# 12                     Alger Growth & Income Z  AGIZX    111949623
# 13                   ALPS/WMC Research Value A  AMWAX     84187995
# 14                   ALPS/WMC Research Value C  AMWCX     84187995
# 15                   ALPS/WMC Research Value I  AMWIX     84187995
# 16                 ALPS/WMC Research Value Inv  AMWYX     84187995
# 17                  Amana Income Institutional  AMINX   1334453577
# 18                       Amana Income Investor  AMANX   1334453577
# 19          American Century Adaptive Equity A  AVDAX    108221583
# 20          American Century Adaptive Equity I  AVDIX    108221583
# 21        American Century Adaptive Equity Inv  AMVIX    108221583
# 22          American Century Adaptive Equity R  AVDRX    108221583
# 23         American Century Adaptive Equity R6  AVDMX    108221583
# 24            American Century Equity Growth A  BEQAX   2830799188
# 25            American Century Equity Growth C  AEYCX   2830799188
# 26            American Century Equity Growth I  AMEIX   2830799188
# 27          American Century Equity Growth Inv  BEQGX   2830799188
# 28            American Century Equity Growth R  AEYRX   2830799188
# 29           American Century Equity Growth R5  AEYGX   2830799188
# 30       American Century Sustainable Equity A  AFDAX    271464263
# 31       American Century Sustainable Equity C  AFDCX    271464263
# 32       American Century Sustainable Equity I  AFEIX    271464263
# 33     American Century Sustainable Equity Inv  AFDIX    271464263
# 34       American Century Sustainable Equity R  AFDRX    271464263
# 35      American Century Sustainable Equity R5  AFDGX    271464263
# 36       American Century Sustainable Equity Y  AFYDX    271464263
# 37        American Funds Fundamental Invs 529A  CFNAX  97504325328
# 38        American Funds Fundamental Invs 529C  CFNCX  97504325328
# ...                                        ...    ...          ...
# 5430      Fidelity Advisor® Consumer Staples C  FDCGX   1425089357
# 5431      Fidelity Advisor® Consumer Staples I  FDIGX   1425089357
# 5432      Fidelity Advisor® Consumer Staples M  FDTGX   1425089357
# 5433      Fidelity Advisor® Consumer Staples Z  FIJCX   1425089357
# 5434    Fidelity® Select Consumer Staples Port  FDFAX   1425089357
# 5435                   ICON Consumer Staples A  ICRAX     10440577
# 5436                   ICON Consumer Staples S  ICLEX     10440577
# 5437                 Rydex Consumer Products A  RYPDX    176839840
# 5438                 Rydex Consumer Products C  RYCPX    176839840
# 5439                 Rydex Consumer Products H  RYCAX    176839840
# 5440               Rydex Consumer Products Inv  RYCIX    176839840
# 5441   Vanguard Consumer Staples Index Admiral  VCSAX   4943253934
# 5444                         US OE Industrials    NaN          NaN
# 5445           Fidelity Advisor® Industrials A  FCLAX    679754632
# 5446           Fidelity Advisor® Industrials C  FCLCX    679754632
# 5447           Fidelity Advisor® Industrials I  FCLIX    679754632
# 5448           Fidelity Advisor® Industrials M  FCLTX    679754632
# 5449           Fidelity Advisor® Industrials Z  FIKEX    679754632
# 5450  Fidelity® Select Air Transportation Port  FSAIX    306770874
# 5451      Fidelity® Select Defense & Aero Port  FSDAX   2790243695
# 5452  Fidelity® Select Envir and Alt Engy Port  FSLEX    160673094
# 5453              Fidelity® Select Industrials  FCYIX    632716448
# 5454           Fidelity® Select Transportation  FSRFX    451290911
# 5455                        ICON Industrials A  ICIAX     13529298
# 5456                        ICON Industrials S  ICTRX     13529298
# 5457                    Rydex Transportation A  RYTSX     18740504
# 5458                    Rydex Transportation C  RYCNX     18740504
# 5459                    Rydex Transportation H  RYPAX     18740504
# 5460                  Rydex Transportation Inv  RYPIX     18740504
# 5461        Vanguard Industrials Index Admiral  VINAX   3271162450
#
# 7    Monthly Return 3/1999 Monthly Return 4/1999 Monthly Return 5/1999  \
# 9                      NaN                   NaN                   NaN
# 10                 5.21277               0.75834              -2.70948
# 11                 5.15575               0.71502              -2.78905
# 12                 5.21277               0.75834              -2.70948
# 13                 5.22496               11.1724               0.12407
# 14                 5.15946               11.1032               0.06174
# 15                 5.39359               11.2033                     0
# 16                 5.22496               11.1724               0.12407
# 17                 1.11821                8.7941              -0.91191
# 18                 1.11821                8.7941              -0.91191
# 19                     NaN                   NaN                   NaN
# 20                     NaN                   NaN                   NaN
# 21                     NaN                   NaN                   NaN
# 22                     NaN                   NaN                   NaN
# 23                     NaN                   NaN                   NaN
# 24                 1.72276               4.26477              -2.17299
# 25                  1.6356               4.17835              -2.25407
# 26                  1.7252                4.3092              -2.17206
# 27                 1.71991               4.26477              -2.17299
# 28                 1.67764               4.22144              -2.21364
# 29                 1.71991               4.26477              -2.17299
# 30                     NaN                   NaN                   NaN
# 31                     NaN                   NaN                   NaN
# 32                     NaN                   NaN                   NaN
# 33                     NaN                   NaN                   NaN
# 34                     NaN                   NaN                   NaN
# 35                     NaN                   NaN                   NaN
# 36                     NaN                   NaN                   NaN
# 37                 4.58971               6.88165              -1.46958
# 38                 4.52547                 6.816               -1.5301
# ...                    ...                   ...                   ...
# 5430              -3.40494              -1.36746               0.03136
# 5431              -3.32481              -1.28564               0.11434
# 5432              -3.36498              -1.32666               0.07274
# 5433              -3.32481              -1.28564               0.11434
# 5434              -3.32481              -1.28564               0.11434
# 5435              -0.33227               8.57116              -2.46634
# 5436              -0.31153               8.59375              -2.44604
# 5437               5.06472               1.29958              -3.92295
# 5438               4.99948               1.23668               -3.9826
# 5439               4.86486               1.42511              -3.79747
# 5440               5.08658               1.32065              -3.90295
# 5441                   NaN                   NaN                   NaN
# 5444                   NaN                   NaN                   NaN
# 5445               1.05605               13.5852              -1.62774
# 5446               0.98603               13.4255              -1.64993
# 5447               1.12631               13.5243               -1.5417
# 5448                0.9772               13.5484              -1.63352
# 5449               1.12631               13.5243               -1.5417
# 5450               4.64697               10.5685              -0.54071
# 5451               0.73855               11.1108               0.84881
# 5452              -2.42756               13.4157                0.9915
# 5453               0.96576                14.087              -1.75305
# 5454               5.55112               14.1664              -1.27412
# 5455              -3.51273               13.5954              -0.77505
# 5456              -3.49265                13.619               -0.7544
# 5457               1.63279               11.1158              -2.83553
# 5458               1.56969               11.0468              -2.89587
# 5459                1.6624               10.8176              -2.83768
# 5460               1.65394               11.1389              -2.81532
# 5461                   NaN                   NaN                   NaN
#
# 7    Monthly Return 6/1999 Monthly Return 7/1999 Monthly Return 8/1999  \
# 9                      NaN                   NaN                   NaN
# 10                 6.08561              -2.04181              -0.79404
# 11                 5.99896              -2.06693              -0.90452
# 12                 6.08561              -2.04181              -0.79404
# 13                -0.24783              -3.22981              -2.56739
# 14                -0.30992              -3.29005              -2.62804
# 15                -0.12438              -3.36239              -2.57732
# 16                -0.24783              -3.22981              -2.56739
# 17                 3.34975              -1.14395              -2.98939
# 18                 3.34975              -1.14395              -2.98939
# 19                     NaN                   NaN                   NaN
# 20                     NaN                   NaN                   NaN
# 21                     NaN                   NaN                   NaN
# 22                     NaN                   NaN                   NaN
# 23                     NaN                   NaN                   NaN
# 24                 6.10383              -1.60428              -0.62709
# 25                 6.07265              -1.64473              -0.70919
# 26                 6.16984              -1.56314              -0.58504
# 27                 6.16064              -1.56314              -0.62683
# 28                 6.11653              -1.60405              -0.66812
# 29                 6.16064              -1.56314              -0.62683
# 30                     NaN                   NaN                   NaN
# 31                     NaN                   NaN                   NaN
# 32                     NaN                   NaN                   NaN
# 33                     NaN                   NaN                   NaN
# 34                     NaN                   NaN                   NaN
# 35                     NaN                   NaN                   NaN
# 36                     NaN                   NaN                   NaN
# 37                 4.21153              -1.33698               -1.2051
# 38                 4.14752              -1.39758              -1.26578
# ...                    ...                   ...                   ...
# 5430               1.12671              -0.55643              -2.96032
# 5431                1.2106              -0.47393              -2.87982
# 5432               1.16854              -0.51529              -2.92018
# 5433                1.2106              -0.47393              -2.87982
# 5434                1.2106              -0.47393              -2.87982
# 5435               1.08516              -8.77172              -3.61718
# 5436               1.10619              -8.75274              -3.59712
# 5437               0.96691              -1.75957              -3.67049
# 5438               0.90422              -1.82057               -3.7303
# 5439               0.98684               -1.9544              -3.65449
# 5440               0.98793              -1.73913              -3.65044
# 5441                   NaN                   NaN                   NaN
# 5444                   NaN                   NaN                   NaN
# 5445               3.81295                -2.079              -1.84006
# 5446               3.71991              -2.18003              -1.86916
# 5447               3.77224              -2.05761              -1.82073
# 5448               3.82671              -2.15577               -1.8479
# 5449               3.77224              -2.05761              -1.82073
# 5450                4.3812               0.58211              -4.93451
# 5451               4.73435              -0.25113              -3.39879
# 5452               6.10098              -11.6325              -15.0337
# 5453               3.95656              -2.23881              -2.21374
# 5454               4.83038               0.03517              -6.22363
# 5455               0.82361              -0.77442              -5.33615
# 5456               0.84459              -0.75377              -5.31646
# 5457              -0.48421              -5.84032              -6.94149
# 5458                -0.546              -5.89878              -6.99927
# 5459              -0.58411              -5.75793              -6.98254
# 5460               -0.4635              -5.82072              -6.92213
# 5461                   NaN                   NaN                   NaN
#
# 7    Monthly Return 9/1999          ...          Monthly Return 5/2018  \
# 9                      NaN          ...                            NaN
# 10                       0          ...                        2.23805
# 11                -0.05071          ...                        2.19242
# 12                       0          ...                        2.28659
# 13                -7.37813          ...                         0.3386
# 14                -7.43578          ...                        0.35672
# 15                -7.40741          ...                        0.32895
# 16                -7.37813          ...                         0.3386
# 17                 -2.6839          ...                        2.37797
# 18                 -2.6839          ...                        2.37203
# 19                     NaN          ...                         3.6379
# 20                     NaN          ...                        3.66361
# 21                     NaN          ...                        3.66894
# 22                     NaN          ...                        3.64716
# 23                     NaN          ...                         3.6214
# 24                -1.55417          ...                        2.59463
# 25                -1.62286          ...                        2.52774
# 26                 -1.5152          ...                        2.64921
# 27                -1.54125          ...                        2.62115
# 28                -1.58216          ...                        2.56254
# 29                -1.54125          ...                        2.61796
# 30                     NaN          ...                        1.81028
# 31                     NaN          ...                         1.7324
# 32                     NaN          ...                        1.87455
# 33                     NaN          ...                        1.87861
# 34                     NaN          ...                        1.81818
# 35                     NaN          ...                        1.87387
# 36                     NaN          ...                        1.87252
# 37                -2.47029          ...                         1.7166
# 38                 -2.5302          ...                        1.63748
# ...                    ...          ...                            ...
# 5430              -5.26187          ...                       -1.95187
# 5431              -5.18328          ...                        -1.8595
# 5432              -5.22268          ...                       -1.91727
# 5433              -5.18328          ...                       -1.86856
# 5434              -5.18328          ...                       -1.86856
# 5435              -0.10371          ...                       -1.42405
# 5436              -0.08292          ...                       -1.25984
# 5437              -9.31853          ...                       -1.44605
# 5438              -9.37483          ...                        -1.5015
# 5439              -9.65517          ...                       -1.46266
# 5440              -9.29966          ...                       -1.42954
# 5441                   NaN          ...                        -1.1448
# 5444                   NaN          ...                            NaN
# 5445               -2.7566          ...                        3.03558
# 5446               -2.8013          ...                        2.97387
# 5447              -2.65559          ...                        3.05253
# 5448              -2.76865          ...                        3.00254
# 5449              -2.65559          ...                        3.05253
# 5450              -8.81128          ...                        3.41959
# 5451              -8.65259          ...                        2.86804
# 5452              -7.57042          ...                         1.8227
# 5453              -2.96643          ...                        3.01508
# 5454              -5.81177          ...                        3.89447
# 5455              -8.12963          ...                        0.97697
# 5456              -8.11052          ...                        1.03235
# 5457              -8.65115          ...                        3.58794
# 5458              -8.70787          ...                        3.52325
# 5459              -8.71314          ...                        3.59657
# 5460              -8.63214          ...                        3.59332
# 5461                   NaN          ...                        3.32135
#
# 7    Monthly Return 6/2018 Monthly Return 7/2018 Monthly Return 8/2018  \
# 9                      NaN                   NaN                   NaN
# 10                 0.51602               4.19876               3.02814
# 11                 0.44429               4.12994               2.95042
# 12                 0.53547               4.22046               3.04907
# 13                       0               3.82452               0.86674
# 14                       0               3.67299               0.91429
# 15                 0.10929               3.71179               0.94737
# 16                       0               3.82452               0.86674
# 17                -0.02053               6.40526               1.27339
# 18                -0.04089               6.38167               1.23053
# 19                 1.71429               0.96308               5.00795
# 20                 1.76707               0.94712                5.0821
# 21                  1.7284               0.97087               5.04808
# 22                 1.63666               0.96618               4.94418
# 23                 1.82685               1.01404               5.01931
# 24                -0.69674               3.57143               2.92669
# 25                -0.78172               3.51515               2.83958
# 26                -0.67161               3.59389               2.97774
# 27                -0.69257               3.59712               2.95139
# 28                -0.72894               3.53929               2.92584
# 29                -0.67161               3.62384               2.94798
# 30                -0.24893               3.92157               3.43053
# 31                -0.28986               3.85174               3.35899
# 32                 -0.2477               3.97304               3.48004
# 5439               -8.64579               5.76635               1.31739
# 5440               -8.62707               5.77536               1.34728
# 5441               -8.98077                5.3323               2.12766
# 5444                    NaN                   NaN                   NaN
# 5445               -10.8585               10.7323               6.61345
# 5446               -10.9149               10.6429               6.55261
# 5447               -10.8441               10.7591               6.63788
# 5448               -10.8737               10.6947               6.59661
# 5449               -10.8188               10.7817               6.62341
# 5450               -13.9863               10.2537               5.42849
# 5451               -9.94504                12.651               8.95899
# 5452               -8.65612               9.36052               5.59322
# 5453               -10.6704               10.7429               6.58268
# 5454               -14.5307               10.4169               3.22406
# 5455               -13.2862               11.9804               5.09461
# 5456               -13.2916               12.0385               5.15759
# 5457               -14.3647               11.9042               2.97073
# 5458               -14.4183                11.841               2.92482
# 5459               -14.3795               11.9162               2.97767
# 5460               -14.3447               11.9323               2.98329
# 5461               -11.0228               11.3625               6.19739
#
# [5419 rows x 243 columns]

# %% [markdown]
# #### TODO
# Separate Large, Mid-Cap, Small, and other categories into separate files.

# %% [markdown]
# #### Decide on Funds
# For now, I'm only going to use large US fund data. I've laid out lists in order to compare mid-cap and small portfolios for later. Will still need to figure out how to drop the right rows when doing small or mid-cap.

# %%
# identify funds by description
# large_names = list(labels.index[["Large" in fund_type for fund_type in labels.index]])
mid_names = list(labels.index[["Mid-Cap" in fund_type for fund_type in labels.index]])
# small_names = list(labels.index[["Small" in fund_type for fund_type in labels.index]])

# decide which rows to skip
fund_types = large_names # + mid_names + small_names
skip_footer = labels.loc[fund_types,'End'].max()

# load data
US_funds = pd.read_excel('../data/US Equity Mutual Funds Monthly Returns.xlsx',
                         header=labels.loc['Columns','Start'], skipfooter=skip_footer)
# drop empty rows
empty_rows = (~US_funds.isna()).sum(axis=1) < 3
US_funds.drop(US_funds.index[empty_rows],axis=0,inplace=True)

# replace missing ticker names with fund name
no_tick = US_funds.index[US_funds.Ticker.isna()]
US_funds.iloc[no_tick,1] = US_funds.iloc[no_tick,0]
US_funds.set_index('Ticker',inplace=True)
US_funds.drop(columns=['Group/Investment','Fund Size'],inplace=True)

# transpose and convert to datetime
funds = US_funds.T
funds.index = pd.to_datetime(funds.index.str.strip('Monthly Return '))

# info
funds.shape
# Out:
# (240, 2712)

# %%
funds.columns
# Out:
# Index(['ALBAX', 'ALBCX', 'AGIZX', 'AMWAX', 'AMWCX', 'AMWIX', 'AMWYX', 'AMINX',
#        'AMANX', 'AVDAX',
#        ...
#        'DTLGX', 'CHCLX', 'CHCYX', 'CHCBX', 'CHCCX', 'CHCIX', 'CHCKX', 'CHCRX',
#        'CHCZX', 'AMGAX'],
#       dtype='object', name='Ticker', length=2712)

# %% [markdown]
# Load factors

# %%
momentum = pd.read_csv('../data/F-F_Momentum_Factor.CSV')
factors = pd.read_csv('../data/F-F_Research_Data_Factors.CSV')
# convert 
for df in [momentum,factors]:
    df['Dates'] = pd.to_datetime(df.Dates.astype(str)\
                                 .apply(lambda x: x[0:4]+'/'+x[4:]),
                                 format="%Y/%m")
    df.set_index('Dates',inplace=True)

factors = pd.merge(factors, momentum, left_index=True, right_index=True)
factors.shape
# Out:
# (1105, 5)

# %% [markdown]
# Line up time of data

# %%
fund_start,fund_end = funds.index.min(),funds.index.max()
fact_start,fact_end = factors.index.min(),factors.index.max()

# clip starts
if fact_start < fund_start:
    factors.drop(factors.index[factors.index < fund_start],inplace=True,axis=0)
else:
    funds.drop(funds.index[funds.index < fact_start],inplace=True,axis=0)
    
# clip ends
if fund_end > fact_end:
    funds.drop(funds.index[funds.index > fact_end],inplace=True,axis=0)
else:
    factors.drop(factors.index[factors.index > fund_end],inplace=True,axis=0)

# check shapes
funds.shape, factors.shape
# Out:
# ((239, 2712), (239, 5))

# %%
# select columns of interest
# take out Mom for 3 factor KAPM
factor_cols = ['Mkt-RF','HML','SMB','RF', 'Mom'] 
factors = factors[factor_cols]

# %%
# funds.to_csv('../data/US Large Funds.csv')
# factors.to_csv('../data/US Large Factors.csv')

# %% [markdown]
# ### Initial Simulation (standard deviation alpha = 0)

# %%
# This code cell runs the data through the AlphaEvaluator object found in
# the luck_v_skill.py file. Creates tables of actual alpha percentiles vs
# simulated alpha percentiles with increasing standard deviation asssumptions
# about injected alpha. The first operation assumes std_alpha = 0.

#----------------------------------------------------------------------------
# OUTPUT PARAMETERS
#----------------------------------------------------------------------------
top_n = 10 # look at top 10 and bottom ten funds, in addition to percentiles
pct_range = np.arange(1,10)/10 # percentiles to consider.  0 < x < 1
verbose = True # keep track of where in program we are at
min_obs = 120 # funds must have at least this many obs to be considered
sim_cutoff = 15 # minimum non-NaN obs in sim_matrix obs for regression
n_simulations = 1000 # number of simulations to run
random_seed = 2 # seed the random number generator here
std_range = np.arange(1,21)/20 # standard deviations of alpha to simulate
n_std = len(std_range) + 1 # number of extra standard deviations evaluating


#----------------------------------------------------------------------------
# START
#----------------------------------------------------------------------------
# Time the program
start_time = time.time()
if verbose:
    title_print("Standard Deviation {} of {}".format(1,n_std))

# initialize instance of the AlphaEvaluator with fund and factor data
AEV = AlphaEvaluator(fund_data=funds,factor_data=factors)

# calculates original coefficients, standard errors, and t-stats
AEV.fit(min_obs=min_obs)



# runs simulations and populates simulated coeff, SE, and tstat matrices
AEV.simulate(n_simulations=n_simulations,random_seed=random_seed,sim_std=0,
             sim_cutoff=sim_cutoff,verbose=verbose)

# populates percentile tables for alpha and t(alpha)
AEV.get_percentiles(pct_range=pct_range,verbose=verbose,top_n=top_n)
data_a, data_t = AEV.data_a.copy(), AEV.data_t.copy()

# Rename data columns
data_a.columns = ['Actual','Sim Avg (0.00)', '%<Act (0.00)']
data_t.columns = ['Actual','Sim Avg (0.00)', '%<Act (0.00)']
# Out:
# --------------------------
# Standard Deviation 1 of 21
# --------------------------
# Annual standard deviation: 0.00, Monthly standard deviation alpha: 0.00
# Starting 2,703,000 regressions...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-4a19b92ab17d> in <module>
#      36 # runs simulations and populates simulated coeff, SE, and tstat matrices
#      37 AEV.simulate(n_simulations=n_simulations,random_seed=random_seed,sim_std=0,
# ---> 38              sim_cutoff=sim_cutoff,verbose=verbose)
#      39
#      40 # populates percentile tables for alpha and t(alpha)
#
# ~/Projects/Fama-French-Funds/src/luck_v_skill.py in simulate(self, n_simulations, random_seed, verbose, sim_std, sim_cutoff, *args, **kwargs)
#     401
#     402                     # HAC OLS and store alpha and t(alpha)
# --> 403                     beta,hac_bse = OLS_HAC(y_sim,x_sim,maxLag=self.maxLag)
#     404                     self._alphas_sim[jj,ss] = beta[0]
#     405                     self._tstats_sim[jj,ss] = beta[0]/hac_bse[0]
#
# ~/Projects/Fama-French-Funds/src/luck_v_skill.py in OLS_HAC(Y, X, add_const, maxLag)
#     123     # add constant if necessary
#     124     if add_const:
# --> 125         x = sm.add_constant(x)
#     126
#     127     # Get Results
#
# /anaconda3/lib/python3.7/site-packages/statsmodels/tools/tools.py in add_constant(data, prepend, has_constant)
#     279     is_nonzero_const = np.ptp(x, axis=0) == 0
#     280     is_nonzero_const &= np.all(x != 0.0, axis=0)
# --> 281     if is_nonzero_const.any():
#     282         if has_constant == 'skip':
#     283             return x
#
# /anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _any(a, axis, dtype, out, keepdims)
#      41
#      42 def _any(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 43     return umr_any(a, axis, dtype, out, keepdims)
#      44
#      45 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Plots

# %%
fig, axes = AEV.plot(plot_type=['cdf','kde','hist'],
                     statistic=['alpha','t-stat'],
                     fund=[-1,0])
plt.tight_layout()
plt.savefig('../charts/US-Large-4factor-plots.png')

# %% [markdown]
# ### More Simulations

# %%
# fill data with more simulations
for i,stdev in enumerate(std_range):
    if verbose:
        title_print("Standard Deviation {} of {}".format(i+2,n_std))
    
    # Rerun simulation with new standard deviation injection for alpha
    AEV.simulate(n_simulations=n_simulations,random_seed=random_seed,
                 sim_std=stdev,sim_cutoff=sim_cutoff,verbose=verbose)
    
    # Update Percentile Data
    AEV.get_percentiles(pct_range=pct_range,verbose=True,top_n=top_n)
    
    # Populate Alpha Percentile Table
    data_a['Sim Avg ({:.2f})'.format(stdev)] = AEV.data_a['Sim Avg']
    data_a['%<Act ({:.2f})'.format(stdev)] = AEV.data_a['%<Act']
    
    # Populate t-statistics Percentile Table
    data_t['Sim Avg ({:.2f})'.format(stdev)] = AEV.data_t['Sim Avg']
    data_t['%<Act ({:.2f})'.format(stdev)] = AEV.data_t['%<Act']


#----------------------------------------------------------------------------
# END
#----------------------------------------------------------------------------

# calculate time elapsed for program and print    
t_diff = time.time()-start_time
minutes = int(np.floor(t_diff/60))
seconds = t_diff - 60*minutes
if verbose:
    print("DONE!")
    print("{} minutes and {:.2f} seconds elapsed for this program".format(minutes,seconds))

# %%
data_a.to_csv('../tables/US-Large-4factor-alphas.csv')
data_t.to_csv('../tables/US-Large-4factor-tstats.csv')

# %%
data_a.shape, data_t.shape
# Out:
# ((29, 43), (29, 43))

# %%
notebook_save()
# Out:
# This notebook has been saved
